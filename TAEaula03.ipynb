# %% [markdown]
# ### **POISSON COM λ=2**

# %% [markdown]
# Para obter P(X = 0):

# %%
dpois(0, lambda = 2)
# Out:
# [1] 0.1353353

# %% [markdown]
# Para obter P(X ≥ 3):

# %%
1 - ppois(2, lambda = 2)
# Out:
# [1] 0.3233236

# %% [markdown]
# Portanto:

# %%
dpois(0, 2)
1 - ppois(2, 2)
# Out:
# [1] 0.1353353
# [1] 0.3233236
